# %% [markdown]
# # Group Member

# %%
import pandas as pd
import os
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
import calendar
import math

os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="./license/APMA4990-834091538ff1.json"

# %% [markdown]
# # Data Gathering and Preparation

# %% [markdown]
# ## Data Pipeline

# %%
from google.cloud import bigquery
client = bigquery.Client()

# %%
query = (
    """
    CREATE TEMP FUNCTION RADIANS(x FLOAT64) as (
        ACOS(-1) * x / 180
    );
    CREATE TEMP FUNCTION RADIANS_TO_KM(x FLOAT64) as (
        111.045 * 180 * x / ACOS(-1)
    );
    CREATE TEMP FUNCTION HAVERSINE(lat1 FLOAT64, long1 FLOAT64,
                                   lat2 FLOAT64, long2 FLOAT64) as (
        RADIANS_TO_KM(
            ACOS(COS(RADIANS(lat1)) * COS(RADIANS(lat2)) *
            COS(RADIANS(long1) - RADIANS(long2)) +
            SIN(RADIANS(lat1)) * SIN(RADIANS(lat2))))
    );
    CREATE TEMP FUNCTION EUCLIDEAN(lat1 FLOAT64, long1 FLOAT64,
                                   lat2 FLOAT64, long2 FLOAT64) as (
        SQRT(POW((long1 - long2),2) + POW((lat1 - lat2), 2))                           
    );
    
    SELECT * FROM 
    (
        SELECT pickup_datetime,dropoff_datetime,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude,
        passenger_count,vendor_id,store_and_fwd_flag,
        EUCLIDEAN(dropoff_latitude, dropoff_longitude, pickup_latitude, pickup_longitude) as euc_distance,
        HAVERSINE(dropoff_latitude, dropoff_longitude, pickup_latitude, pickup_longitude) as hav_distance,
        EXTRACT (DATE FROM pickup_datetime) as date,
        EXTRACT (MONTH FROM pickup_datetime) as month,
        EXTRACT (DAYOFWEEK FROM pickup_datetime) as day,
        EXTRACT (YEAR FROM pickup_datetime) as year,
        EXTRACT (HOUR from pickup_datetime) as hour,
        TIMESTAMP_DIFF(dropoff_datetime, pickup_datetime, SECOND) as trip_duration
        FROM `bigquery-public-data.new_york.tlc_yellow_trips_2016`
        
        WHERE pickup_longitude > -75
        AND pickup_longitude < -73
        AND dropoff_longitude > -75
        AND dropoff_longitude < -73
        AND pickup_latitude > 40
        AND pickup_latitude < 42
        AND dropoff_latitude > 40
        AND dropoff_latitude < 42
        AND HAVERSINE(dropoff_latitude, dropoff_longitude, pickup_latitude, pickup_longitude) BETWEEN 0.1 AND 40
        AND passenger_count BETWEEN 1 AND 4
        AND TIMESTAMP_DIFF(dropoff_datetime, pickup_datetime, SECOND) BETWEEN 60 AND 3600
    ) trip
    INNER JOIN
    (
     SELECT CONCAT(year,'-',mo,'-',da) as date2,temp,visib,wdsp,gust,max,min,prcp,sndp,fog,rain_drizzle,snow_ice_pellets,hail,thunder
     FROM `bigquery-public-data.noaa_gsod.gsod2016` 
     WHERE stn = '725053'
     AND temp != 9999.9
     AND visib != 999.9
     AND wdsp != '999.9'
     AND gust != 999.9
     AND max != 9999.9
     AND min != 9999.9
     AND prcp != 99.99
     AND sndp != 999.9
    ) weather
    on CAST(trip.date AS STRING) = weather.date2
    
    ORDER BY RAND()
    LIMIT 10000
    """
)
df=pd.io.gbq.read_gbq(query,dialect='standard')
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# E:\Anaconda\lib\site-packages\pandas_gbq\gbq.py in run_query(self, query, **kwargs)
#     471             try:
# --> 472                 query_reply.result(timeout=timeout_sec)
#     473             except TimeoutError:
#
# E:\Anaconda\lib\site-packages\google\cloud\bigquery\job.py in result(self, timeout, retry)
#    2793         """
# -> 2794         super(QueryJob, self).result(timeout=timeout)
#    2795         # Return an iterator instead of returning the job.
#
# E:\Anaconda\lib\site-packages\google\cloud\bigquery\job.py in result(self, timeout, retry)
#     706         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 707         return super(_AsyncJob, self).result(timeout=timeout)
#     708
#
# E:\Anaconda\lib\site-packages\google\api_core\future\polling.py in result(self, timeout)
#     121         """
# --> 122         self._blocking_poll(timeout=timeout)
#     123
#
# E:\Anaconda\lib\site-packages\google\cloud\bigquery\job.py in _blocking_poll(self, timeout)
#    2767         self._done_timeout = timeout
# -> 2768         super(QueryJob, self)._blocking_poll(timeout=timeout)
#    2769
#
# E:\Anaconda\lib\site-packages\google\api_core\future\polling.py in _blocking_poll(self, timeout)
#     100         try:
# --> 101             retry_(self._done_or_raise)()
#     102         except exceptions.RetryError:
#
# E:\Anaconda\lib\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     269                 self._deadline,
# --> 270                 on_error=on_error,
#     271             )
#
# E:\Anaconda\lib\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     178         try:
# --> 179             return target()
#     180
#
# E:\Anaconda\lib\site-packages\google\api_core\future\polling.py in _done_or_raise(self)
#      79         """Check if the future is done and raise if it's not."""
# ---> 80         if not self.done():
#      81             raise _OperationNotComplete()
#
# E:\Anaconda\lib\site-packages\google\cloud\bigquery\job.py in done(self, retry)
#    2754                 timeout_ms=timeout_ms,
# -> 2755                 location=self.location,
#    2756             )
#
# E:\Anaconda\lib\site-packages\google\cloud\bigquery\client.py in _get_query_results(self, job_id, retry, project, timeout_ms, location)
#     861         resource = self._call_api(
# --> 862             retry, method="GET", path=path, query_params=extra_params
#     863         )
#
# E:\Anaconda\lib\site-packages\google\cloud\bigquery\client.py in _call_api(self, retry, **kwargs)
#     403             call = retry(call)
# --> 404         return call()
#     405
#
# E:\Anaconda\lib\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     269                 self._deadline,
# --> 270                 on_error=on_error,
#     271             )
#
# E:\Anaconda\lib\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     178         try:
# --> 179             return target()
#     180
#
# E:\Anaconda\lib\site-packages\google\cloud\_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     318         if not 200 <= response.status_code < 300:
# --> 319             raise exceptions.from_http_response(response)
#     320
#
# BadRequest: 400 GET https://www.googleapis.com/bigquery/v2/projects/apma4990/queries/20d181c0-6599-41bb-9005-fb5d9ce0ef82?maxResults=0&timeoutMs=900&location=US: Floating point error in function: ACOS(1)
#
# During handling of the above exception, another exception occurred:
#
# GenericGBQException                       Traceback (most recent call last)
# <ipython-input-3-d42b2831fbf6> in <module>
#      65     """
#      66 )
# ---> 67 df=pd.io.gbq.read_gbq(query,dialect='standard')
#
# E:\Anaconda\lib\site-packages\pandas\io\gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, private_key, verbose)
#     147         auth_local_webserver=auth_local_webserver, dialect=dialect,
#     148         location=location, configuration=configuration,
# --> 149         credentials=credentials, verbose=verbose, private_key=private_key)
#     150
#     151
#
# E:\Anaconda\lib\site-packages\pandas_gbq\gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, verbose, private_key)
#     925     )
#     926
# --> 927     final_df = connector.run_query(query, configuration=configuration)
#     928
#     929     # Reindex the DataFrame on the provided column
#
# E:\Anaconda\lib\site-packages\pandas_gbq\gbq.py in run_query(self, query, **kwargs)
#     475                 pass
#     476             except self.http_error as ex:
# --> 477                 self.process_http_error(ex)
#     478
#     479         if query_reply.cache_hit:
#
# E:\Anaconda\lib\site-packages\pandas_gbq\gbq.py in process_http_error(ex)
#     402         # <https://cloud.google.com/bigquery/troubleshooting-errors>`__
#     403
# --> 404         raise GenericGBQException("Reason: {0}".format(ex))
#     405
#     406     def run_query(self, query, **kwargs):
#
# GenericGBQException: Reason: 400 GET https://www.googleapis.com/bigquery/v2/projects/apma4990/queries/20d181c0-6599-41bb-9005-fb5d9ce0ef82?maxResults=0&timeoutMs=900&location=US: Floating point error in function: ACOS(1)

# %%
df.to_csv('data.csv',index=False)

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#              pickup_datetime           dropoff_datetime  pickup_longitude  \
# 0  2016-01-24 21:33:16+00:00  2016-01-24 22:07:05+00:00        -73.781517
# 1  2016-01-26 18:21:07+00:00  2016-01-26 19:07:35+00:00        -73.863167
# 2  2016-02-01 07:08:02+00:00  2016-02-01 07:46:59+00:00        -74.016846
# 3  2016-02-01 20:03:23+00:00  2016-02-01 20:28:08+00:00        -73.776787
# 4  2016-01-24 14:49:29+00:00  2016-01-24 15:31:03+00:00        -73.776855
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0        40.644882         -73.989052         40.758224                1
# 1        40.769909         -74.005333         40.722221                1
# 2        40.706230         -73.944382         40.841209                1
# 3        40.645187         -73.912422         40.780499                3
# 4        40.645458         -73.973389         40.779758                1
#
#    vendor_id store_and_fwd_flag  euc_distance  ...  gust   max   min  prcp  \
# 0          1                  N      0.236468  ...  26.0  35.1  19.9  1.82
# 1          2                  N      0.149951  ...  25.1  48.0  28.0  0.00
# 2          1                  N      0.153201  ...  18.1  59.0  36.0  0.00
# 3          2                  N      0.191588  ...  18.1  59.0  36.0  0.00
# 4          1                  N      0.238038  ...  26.0  35.1  19.9  1.82
#
#    sndp  fog  rain_drizzle snow_ice_pellets  hail  thunder
# 0   5.9    1             0                1     0        0
# 1  18.9    0             0                0     0        0
# 2   3.9    0             1                0     0        0
# 3   3.9    0             1                0     0        0
# 4   5.9    1             0                1     0        0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (100000, 31)

# %% [markdown]
# We fetch data directly from Big Query: `bigquery-public-data.new_york.tlc_yellow_trips_2016`, but delete some useless and unreliable features: payment_type, fare_amount, extra, mta_tax, imp_surcharge, tip_amount, tolls_amount and total_amount from the original dataset. Then we add month, year and trip_duration as additional features.

# %% [markdown]
# ## Data Integrity Check

# %% [markdown]
#  - **pickup_datetime** - date and time when the meter was engaged
#  - **dropoff_datetime** - date and time when the meter was disengaged
#  - **pickup_longitude** - the longitude where the meter was engaged
#  - **pickup_latitude** - the latitude where the meter was engaged
#  - **dropoff_longitude** - the longitude where the meter was disengaged
#  - **dropoff_latitude** - the latitude where the meter was disengaged
#  - **passenger_count** - the number of passengers in the vehicle (driver entered value)
#  - **vendor_id** - a code indicating the provider associated with the trip record
#  - **store_and_fwd_flag** - This flag indicates whether the trip record was held in vehicle memory before sending to the vendor because the vehicle did not have a connection to the server (Y=store and forward; N=not a store and forward trip)
#  - **trip_duration** - duration of the trip in seconds

# %%
check_NAN_box = []

for i in df.columns:
    check_NAN_box.append(df[i].isnull().any())

check_NAN_box = pd.DataFrame([check_NAN_box],columns=df.columns)
np.unique(check_NAN_box.values)
# Out:
# array([False])

# %%
check_uni_box = []
col = ['vendor_id','store_and_fwd_flag','year','fog','rain_drizzle','snow_ice_pellets','hail','thunder']

for i in col:
    check_uni_box.append(df[i].unique())

check_uni_box = pd.DataFrame([check_uni_box],columns=col)
check_uni_box
# Out:
#   vendor_id store_and_fwd_flag    year     fog rain_drizzle snow_ice_pellets  \
# 0    [1, 2]             [N, Y]  [2016]  [1, 0]       [0, 1]           [1, 0]
#
#   hail thunder
# 0  [0]     [0]

# %%
def preprocess(data):
    tmp = data[data['year']==2016]
    tmp = tmp[tmp['vendor_id'].isin(['1','2','3'])]
    tmp = tmp[tmp['store_and_fwd_flag'].isin(['Y','N'])]
    tmp = tmp[tmp['fog'].isin(['0','1'])]
    tmp = tmp[tmp['rain_drizzle'].isin(['0','1'])]
    tmp = tmp[tmp['snow_ice_pellets'].isin(['0','1'])]
    tmp = tmp[tmp['hail'].isin(['0','1'])]
    tmp = tmp[tmp['thunder'].isin(['0','1'])]
    
    tmp['store_and_fwd_flag'] = 1 * (tmp['store_and_fwd_flag'].values == 'Y')
    return tmp

data = preprocess(df)

# %%
data.shape
# Out:
# (100000, 31)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Trip distance and duration distribution

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))

ax[0].hist(data['hav_distance'].values, bins=300)
ax[0].set_xlabel('trip distance(miles)')
ax[0].set_ylabel('number of records')

ax[1].hist(data['trip_duration'].values, bins=60)
ax[1].set_xlabel('trip duration (log(s))')
ax[1].set_ylabel('number of records')

plt.show()

# %%
data.plot(x='hav_distance',y='trip_duration',kind='scatter')

# %% [markdown]
# ### Correlation

# %%
corr = data.corr()
sns.heatmap(corr)

# %% [markdown]
# ### Trip frequency

# %%
weekDays = ("Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday")

plt.plot(data.groupby('day').count(),'o-')
plt.title('Trip frequency(month)')
plt.ylabel('number of records')
plt.xticks(np.arange(1,8),weekDays)
plt.show()

# %% [markdown]
# ### Start point distribution

# %%
city_long_border = (-74.03, -73.75)
city_lat_border = (40.63, 40.85)
plt.scatter(data['pickup_longitude'].values[:len(data)], data['pickup_latitude'].values[:len(data)],
              color='blue', s=1, label='train', alpha=0.1)
plt.ylabel('latitude')
plt.xlabel('longitude')
plt.ylim(city_lat_border)
plt.xlim(city_long_border)
plt.show()

# %% [markdown]
# # Model Selection, Comparison and Cross Validation

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# ## Model Selection
